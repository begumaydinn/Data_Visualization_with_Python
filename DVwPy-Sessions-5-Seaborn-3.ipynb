# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'tips', 'titanic']

# %%
penguins = sns.load_dataset("penguins")
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.heatmap(penguins.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(penguins.isnull())
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(16,8))
sns.heatmap(penguins.isnull())
# Out:
# <AxesSubplot:>

# %%
sns.catplot(data = penguins, x="species", y="bill_length_mm")

# %%
sns.catplot(data = penguins, x="species", y="bill_length_mm", kind="bar") #estimator bize otomatik mean alır

# %%
sns.catplot(data = penguins, x="species", y="bill_length_mm", kind="bar") 
#buna ci= %95 bize standart sapmanın etkinliğinş verir çigiler ne kadar kısa ise o kadar iyi veri yğunluğu fazla
# çizgi uzunluğu ne kadar fazla ise hata olasılığı o kadar yüksek olabilir güvenirlik azalır sapma fazla grafik tepe noktası sivri değil dağılımlı 
#çizgi ne kadar kısa ise veri o kadar güvenilir hata az grafik sivri
# ci en fazla 100 alabilir fazla almaz error verir. 80 ile 95 iyi bir değer aralığı olacaktır.

# %%
sns.catplot(data = penguins, x="species", y="bill_length_mm", kind="bar", estimator=np.min, ci="sd")

# %%
sns.catplot(data = penguins, x="species", y="bill_length_mm", kind="bar",estimator=np.count_nonzero)

# %%
sns.catplot(data = penguins, x="species", y="bill_length_mm", kind="bar",estimator=np.median, ci="sd", col="island")

# %%
sns.catplot(data = penguins, x="species", y="bill_length_mm", kind="bar",estimator=np.median, ci="sd", col="island", row="sex")

# %%
sns.catplot(data = penguins, x="species", y="bill_length_mm", kind="bar",estimator=np.median, ci="sd", col="island", hue="sex")

# %%
sns.catplot(data = penguins, x="species", y="bill_length_mm", kind="box", col="island", row="sex")

# %%
sns.catplot(data = penguins, x="species", y="bill_length_mm", kind="box", col="island", hue="sex")

# %%
sns.catplot(data = penguins, x="island", y="bill_length_mm", kind="box", col="species", hue="sex")

# %%
sns.jointplot(data = penguins, x="bill_depth_mm", y="bill_length_mm")

# %%
sns.jointplot(data = penguins, x="bill_depth_mm", y="bill_length_mm", hue="species")

# %%
sns.jointplot(data = penguins, x="flipper_length_mm", y="bill_length_mm", hue="species")

# %%
sns.jointplot(data = penguins, x="body_mass_g", y="bill_length_mm", hue="species")

# %%
sns.jointplot(data = penguins, x="body_mass_g", y="bill_length_mm", kind="hex")

# %%
sns.jointplot(data = penguins, x="body_mass_g", y="flipper_length_mm", kind="kde", hue="species")

# %% [markdown]
# ## Pairplot

# %%
sns.pairplot(penguins)

# %%
sns.pairplot(penguins, hue="species", palette="viridis")

# %%
sns.set_palette(['green', 'purple', 'red'])
sns.pairplot(penguins, hue="species")

# %%
sns.set_palette(['green', 'purple', 'red'])
sns.pairplot(penguins, hue="species", corner=True)

# %%
sns.set_palette(['green', 'purple', 'red'])
sns.pairplot(penguins, hue="species", corner=True, diag_kind="hist")

# %% [markdown]
# ## PairGrid

# %%
sns.PairGrid(penguins)

# %%
g = sns.PairGrid(penguins)
g.map(sns.scatterplot)

# %%
g = sns.PairGrid(penguins, hue="species")
g.map(sns.scatterplot)

# %%
g = sns.PairGrid(penguins, hue="species")
g.map_diag(sns.kdeplot)

# %%
g = sns.PairGrid(penguins, hue="species")
g.map_diag(sns.histplot)

# %%
g = sns.PairGrid(penguins, hue="species")
g.map_diag(sns.histplot)
g.map_lower(sns.kdeplot)
g.map_upper(sns.scatterplot)

# %%
g = sns.PairGrid(penguins)
g.map_diag(sns.histplot)
g.map_lower(sns.kdeplot)
g.map_upper(sns.scatterplot)

# %%
sns.set_palette(["green", "blue", "red"])
g = sns.PairGrid(penguins, hue="species")
g.map_diag(sns.kdeplot)
g.map_lower(sns.kdeplot)
g.map_upper(sns.scatterplot)

g.add_legend()

# sağ alt köşede sıkıntı var diag_sharey true o yuzden ortak kullanıyor y eksenini

# %%
sns.set_palette(["green", "blue", "red"])
g = sns.PairGrid(penguins, hue="species", diag_sharey=False)
#y eksenini ortak almasın diye  eger true olsaydı yukarıdaki sağ alt köşe gibi olurdu
g.map_diag(sns.kdeplot)
g.map_lower(sns.kdeplot)
g.map_upper(sns.scatterplot)

g.add_legend()

# %%
g = sns.FacetGrid(data=penguins)
g.map(sns.histplot,"bill_length_mm")

# %%
g = sns.FacetGrid(data=penguins, col="species", row="island", hue="sex")
g.map(sns.histplot,"bill_length_mm")

# %%
g = sns.FacetGrid(data=penguins, col="species", row="island", hue="sex")
g.map(sns.kdeplot,"bill_length_mm")

# %%
g = sns.FacetGrid(data=penguins, col="species", row="island", hue="sex")
g.map(sns.scatterplot,"bill_length_mm", "body_mass_g")

# %%
plt.figure(figsize=(16,9))
sns.heatmap(penguins.notnull())
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(16,9))
sns.heatmap(penguins.corr())
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(16,9))
sns.heatmap(penguins.corr(), annot = True);

# %%
plt.figure(figsize=(16,9))
sns.heatmap(penguins.corr(), annot = True, cmap = "viridis", center = 0.66);

# %%
plt.figure(figsize=(16,9))
sns.heatmap(penguins.corr(), annot = True, cmap = "viridis", center = -1); 
# center = -1 ile 1 arasında bir değer vererek renk merkezini seçebiliriz

# %%
sns.clustermap(penguins.corr());

# %%
sns.clustermap(penguins.corr(), annot = True);

# %%
plt.figure(figsize=(16,9))
sns.heatmap(penguins.corr(), annot = True, cmap = "coolwarm");
