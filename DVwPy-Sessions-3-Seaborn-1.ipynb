# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
diamonds=sns.load_dataset('diamonds')
exercise=sns.load_dataset('exercise')
flights=sns.load_dataset('flights')
geyser=sns.load_dataset('geyser')
iris=sns.load_dataset('iris')
penguins=sns.load_dataset('penguins')
planets=sns.load_dataset('planets')
mpg=sns.load_dataset('mpg')
tips = sns.load_dataset('tips')
titanic=sns.load_dataset('titanic')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips["size"].unique()
# Out:
# array([2, 3, 4, 1, 6, 5])

# %%
sns.scatterplot(x ='total_bill', y ="tip", data = tips);

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data = tips, x ="total_bill", y ="tip", hue ="smoker");

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data = tips[tips.smoker=="No"], x = "total_bill", y ="tip");

# %%
plt.figure(figsize=(10,5))
sns.scatterplot( x =tips["total_bill"], y =tips["tip"], hue =tips["smoker"]);

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data = tips, x ="total_bill", y ="tip", style="sex");

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data = tips, x ="total_bill", y ="tip", style="sex", hue="sex");

# %%
plt.figure(figsize=(10,5))
markers={"Male":">", "Female":"<"}
sns.scatterplot(data = tips, x ="total_bill", y ="tip", style="sex", hue="sex", markers=markers);

# %%
plt.figure(figsize=(10,5))
markers={"Male":">", "Female":"<"}
sns.scatterplot(data = tips, x ="total_bill", y ="tip", style="sex", hue="sex", markers=markers, s=150);

# %%
plt.figure(figsize=(10,5))
markers={"Male":"*", "Female":","}
sns.scatterplot(data = tips, x ="total_bill", y ="tip", style="sex", hue="sex", markers=markers);

# %%
fig, ax =plt.subplots(1,2, figsize=(10,5))
sns.scatterplot(data = tips, x ="total_bill", y ="tip", style="sex", hue="sex", ax=ax[0]);
sns.scatterplot(data = tips, x ="total_bill", y ="tip", hue="day", ax=ax[1]);

# %%
sns.scatterplot(data = tips, x ="total_bill", y ="tip", style="sex", hue="sex", palette="plasma");

# %%
sns.scatterplot(data = tips, x ="total_bill", y ="tip", style="sex", hue="sex", palette="plasma",size="smoker");

# %%
sns.scatterplot(data = tips, x ="total_bill", y ="tip", hue="sex", palette="plasma");

# %%
fig, ax =plt.subplots(figsize=(10,5))
sns.scatterplot(data = tips, x ="total_bill", y ="tip", alpha=0.7, palette="plasma");

# %%
fig, ax =plt.subplots(figsize=(12,6))
sns.scatterplot(data = tips, x ="total_bill", y ="tip", s=300, hue="sex");

# %%
fig, ax =plt.subplots(figsize=(12,6))
sns.scatterplot(data = tips, x ="total_bill", y ="tip", s=150, hue="sex");

# %%
fig, ax =plt.subplots(figsize=(12,6))
sns.scatterplot(data = tips, x ="total_bill", y ="tip", s=300, hue="sex", alpha=0.7);

# %% [markdown]
# ## Rugplot

# %%
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
sns.rugplot(data=mpg, x ="weight");

# %%
sns.rugplot(data=mpg, x ="weight", height=0.5);

# %%
sns.displot(data=mpg, x ="weight");

# %%
fig, ax= plt.subplots(1,2,figsize=(10,5))
sns.scatterplot(data=tips, x='total_bill',y='tip', s=300, hue='sex', ax=ax[0])
sns.histplot(data=mpg, x='weight', ax=ax[1]);
# sns.displot(data=mpg, x='weight', ax=ax[1]);

# %%
sns.displot(data=mpg, x="weight", kind="hist");
sns.displot(data=mpg, x="weight", kind="kde");

# %%
plt.figure(figsize=(6,4))
sns.histplot(data=mpg, x='weight');

# %%
sns.displot(data=mpg, x="weight", kind="ecdf");

# %%
fig, ax= plt.subplots(1,2,figsize=(10,5))
sns.rugplot(data=tips, x='total_bill',ax=ax[1])
sns.histplot(data=mpg, x='weight', kde=True, ax=ax[0]);

# %%
sns.displot(data=mpg, x='weight', kde=True, aspect=2);

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=mpg, x='weight', bins=20);

# %%
plt.subplot(1,2,1)
sns.rugplot(data=mpg, x = "weight", height=0.5)
plt.subplot(1,2,2)
sns.histplot(data=mpg, x = "weight", kde=True)
# Out:
# <AxesSubplot:xlabel='weight', ylabel='Count'>

# %%
sns.set(style="dark")
sns.histplot(data=mpg, x = "weight", kde=True)
# Out:
# <AxesSubplot:xlabel='weight', ylabel='Count'>

# %% [markdown]
# ## KDE

# %%
sns.kdeplot(data=penguins, x="body_mass_g");

# %%
sns.kdeplot(data=penguins, x="body_mass_g", hue="sex");

# %%
sns.kdeplot(data=penguins, x="body_mass_g", hue="sex", shade=True);

# %%
sns.kdeplot(data=penguins, x="bill_length_mm", hue="sex", shade=True);

# %%
sns.kdeplot(data=tips, x="total_bill", y="tip");

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip");

# %%
sns.kdeplot(data=tips, x="total_bill", y="tip", color="red");

# %%
sns.kdeplot(data=tips, x="total_bill", y="tip", color="red", shade=True);

# %%
fig, ax=plt.subplots(1,2, figsize=(12,8
                                  ))
sns.scatterplot(data=tips, x='total_bill', y='tip', ax=ax[0]);
sns.kdeplot(data=tips, x='total_bill', y='tip', color='red', shade=True, ax=ax[1]);

# %%
sns.displot(data=penguins,
           x="body_mass_g",
            bins=10,
            rug=True,
            kde=True)

# %%
# kind : {"scatter"/"kde"/"hist"/"hex"/"reg"/"resid"}
sns.jointplot(data=tips, x="total_bill", y="tip", kind="scatter")

# %%
sns.jointplot(data=tips, x="total_bill", y="tip", kind="hist")

# %%
sns.jointplot(data=tips, x="total_bill", y="tip", kind="hex")

# %%
sns.jointplot(data=mpg, x="cylinders", y="horsepower")

# %%
sns.jointplot(data=mpg, x="horsepower", y="acceleration")
